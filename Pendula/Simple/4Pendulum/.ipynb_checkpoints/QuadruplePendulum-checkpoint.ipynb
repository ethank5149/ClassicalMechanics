# %%
from sympy.physics.mechanics import *
import sympy as sp
mechanics_printing(pretty_print=True)

# %%
m1, m2, m3, m4, l1, l2, l3, l4 = sp.symbols(r'm_1 m_2 m_3 m_4 l_1 l_2 l_3 l_4')
t, g, h = sp.symbols('t g h')
v1, v2, v3, v4 = dynamicsymbols(r'\theta_1 \theta_2 \theta_3 \theta_4')
dv1, dv2, dv3, dv4 = dynamicsymbols(r'\theta_1 \theta_2 \theta_3 \theta_4', 1)
ddv1, ddv2, ddv3, ddv4 = dynamicsymbols(r'\theta_1 \theta_2 \theta_3 \theta_4', 2)

# %%
x1 = l1 * sp.sin(v1)
y1 = -l1 * sp.cos(v1)
x2 = x1 + l2 * sp.sin(v2)
y2 = y1 + -l2 * sp.cos(v2)
x3 = x2 + l3 * sp.sin(v3)
y3 = y2 + -l3 * sp.cos(v3)
x4 = x3 + l4 * sp.sin(v4)
y4 = y3 + -l4 * sp.cos(v4)

dx1 = x1.diff(t)
dy1 = y1.diff(t)
dx2 = x2.diff(t)
dy2 = y2.diff(t)
dx3 = x3.diff(t)
dy3 = y3.diff(t)
dx4 = x4.diff(t)
dy4 = y4.diff(t)

# %%
V = (m1 * g * y1) + (m2 * g * y2) + (m3 * g * y3) + (m4 * g * y4)
T = (sp.Rational(1, 2) * m1 * (dx1**2 + dy1**2)) + (sp.Rational(1, 2) * m2 * (dx2**2+dy2**2)) + (sp.Rational(1, 2) * m3 * (dx3**2 + dy3**2)) + (sp.Rational(1, 2) * m4 * (dx4**2 + dy4**2))
L = T - V

# %%
LM = LagrangesMethod(L, [v1, v2, v3, v4])

# %%
soln = LM.form_lagranges_equations()

# %%
sp.latex(soln)
# Out:
# ⎡
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢g⋅l₁⋅m₁⋅sin(\theta₁(t)) + g⋅l₁⋅m₂⋅sin(\theta₁(t)) + g⋅l₁⋅m₃⋅sin(\theta₁(t)) +
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢                                                        g⋅l₂⋅m₂⋅sin(\theta₂(t
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎢
# ⎣
#
#                               ⎛                         2
#                               ⎜    2    2              d                    2
#                            m₁⋅⎜2⋅l₁ ⋅sin (\theta₁(t))⋅───(\theta₁(t)) + 2⋅l₁ ⋅
#                               ⎜                         2
#                               ⎝                       dt
#  g⋅l₁⋅m₄⋅sin(\theta₁(t)) + ───────────────────────────────────────────────────
#                                                                     2
#
#
#
#                                                             ⎛     ⎛
#                                                          m₂⋅⎜2⋅l₂⋅⎜l₁⋅sin(\the
#                                                             ⎝     ⎝
# )) + g⋅l₂⋅m₃⋅sin(\theta₂(t)) + g⋅l₂⋅m₄⋅sin(\theta₂(t)) - ─────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                    2            ⎞
#    2              d             ⎟
# cos (\theta₁(t))⋅───(\theta₁(t))⎟      ⎛     ⎛                   d
#                    2            ⎟   m₂⋅⎜2⋅l₁⋅⎜l₁⋅sin(\theta₁(t))⋅──(\theta₁(t)
#                  dt             ⎠      ⎝     ⎝                   dt
# ───────────────────────────────── - ──────────────────────────────────────────
#
#
#
#
#         d                                   d             ⎞                 d
# ta₁(t))⋅──(\theta₁(t)) + l₂⋅sin(\theta₂(t))⋅──(\theta₂(t))⎟⋅cos(\theta₂(t))⋅──
#         dt                                  dt            ⎠                 dt
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                        d             ⎞                 d                     ⎛
# ) + l₂⋅sin(\theta₂(t))⋅──(\theta₂(t))⎟⋅cos(\theta₁(t))⋅──(\theta₁(t)) - 2⋅l₁⋅⎜
#                        dt            ⎠                 dt                    ⎝
# ──────────────────────────────────────────────────────────────────────────────
#                                                                     2
#
#
#
#                     ⎛                   d                                   d
# (\theta₂(t)) - 2⋅l₂⋅⎜l₁⋅cos(\theta₁(t))⋅──(\theta₁(t)) + l₂⋅cos(\theta₂(t))⋅──
#                     ⎝                   dt                                  dt
# ──────────────────────────────────────────────────────────────────────────────
#            2
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                    d                                   d             ⎞
# l₁⋅cos(\theta₁(t))⋅──(\theta₁(t)) + l₂⋅cos(\theta₂(t))⋅──(\theta₂(t))⎟⋅sin(\th
#                    dt                                  dt            ⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                                                    ⎛
#                                                    ⎜     ⎛                   d
#             ⎞                 d             ⎞   m₂⋅⎜2⋅l₂⋅⎜l₁⋅sin(\theta₁(t))⋅─
# (\theta₂(t))⎟⋅sin(\theta₂(t))⋅──(\theta₂(t))⎟      ⎜     ⎝                   d
#             ⎠                 dt            ⎠      ⎝
# ───────────────────────────────────────────── + ──────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                               ⎛
#                               ⎜     ⎛                   d
#          d             ⎞   m₂⋅⎜2⋅l₁⋅⎜l₁⋅sin(\theta₁(t))⋅──(\theta₁(t)) + l₂⋅si
# eta₁(t))⋅──(\theta₁(t))⎟      ⎜     ⎝                   dt
#          dt            ⎠      ⎝
# ──────────────────────── + ───────────────────────────────────────────────────
#
#
#
#                                    d             ⎞                 d
# ─(\theta₁(t)) + l₂⋅sin(\theta₂(t))⋅──(\theta₂(t))⎟⋅cos(\theta₂(t))⋅──(\theta₂(
# t                                  dt            ⎠                 dt
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#               d             ⎞                 d                     ⎛
# n(\theta₂(t))⋅──(\theta₂(t))⎟⋅cos(\theta₁(t))⋅──(\theta₁(t)) - 2⋅l₁⋅⎜l₁⋅cos(\t
#               dt            ⎠                 dt                    ⎝
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#            ⎛                   d                                   d
# t)) - 2⋅l₂⋅⎜l₁⋅cos(\theta₁(t))⋅──(\theta₁(t)) + l₂⋅cos(\theta₂(t))⋅──(\theta₂(
#            ⎝                   dt                                  dt
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#                                                           ⎛     ⎛
#                                                        m₃⋅⎜2⋅l₃⋅⎜l₁⋅sin(\theta
#                                                           ⎝     ⎝
#    g⋅l₃⋅m₃⋅sin(\theta₃(t)) + g⋅l₃⋅m₄⋅sin(\theta₃(t)) - ───────────────────────
#
#
#
#
#
#
#
#
#
#
#
#           d                                   d             ⎞
# heta₁(t))⋅──(\theta₁(t)) + l₂⋅cos(\theta₂(t))⋅──(\theta₂(t))⎟⋅sin(\theta₁(t))⋅
#           dt                                  dt            ⎠
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                                            ⎛
#    ⎞                 d                     ⎜                     ⎛d
# t))⎟⋅sin(\theta₂(t))⋅──(\theta₂(t)) + 2⋅l₂⋅⎜- l₁⋅sin(\theta₁(t))⋅⎜──(\theta₁(t
#    ⎠                 dt                    ⎜                     ⎝dt
#                                            ⎝
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#       d                                   d
# ₁(t))⋅──(\theta₁(t)) + l₂⋅sin(\theta₂(t))⋅──(\theta₂(t)) + l₃⋅sin(\theta₃(t))⋅
#       dt                                  dt
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#                       ⎛                                     2
# d                     ⎜                     ⎛d             ⎞
# ──(\theta₁(t)) + 2⋅l₁⋅⎜- l₁⋅sin(\theta₁(t))⋅⎜──(\theta₁(t))⎟  + l₁⋅cos(\theta₁
# dt                    ⎜                     ⎝dt            ⎠
#                       ⎝
# ──────────────────────────────────────────────────────────────────────────────
#
#
#    2                        2
#   ⎞                        d                                   ⎛d
# ))⎟  + l₁⋅cos(\theta₁(t))⋅───(\theta₁(t)) - l₂⋅sin(\theta₂(t))⋅⎜──(\theta₂(t))
#   ⎠                         2                                  ⎝dt
#                           dt
# ──────────────────────────────────────────────────────────────────────────────
#                       2
#
#
#
# d             ⎞                 d                     ⎛                   d
# ──(\theta₃(t))⎟⋅cos(\theta₃(t))⋅──(\theta₃(t)) - 2⋅l₃⋅⎜l₁⋅cos(\theta₁(t))⋅──(\
# dt            ⎠                 dt                    ⎝                   dt
# ──────────────────────────────────────────────────────────────────────────────
#                                              2
#
#
#
#
#
#
#
#
#
#        2                                                  2
#       d                                   ⎛d             ⎞
# (t))⋅───(\theta₁(t)) - l₂⋅sin(\theta₂(t))⋅⎜──(\theta₂(t))⎟  + l₂⋅cos(\theta₂(t
#        2                                  ⎝dt            ⎠
#      dt
# ──────────────────────────────────────────────────────────────────────────────
#  2
#
#  2                        2            ⎞                        ⎛
# ⎞                        d             ⎟                        ⎜
# ⎟  + l₂⋅cos(\theta₂(t))⋅───(\theta₂(t))⎟⋅cos(\theta₂(t)) + 2⋅l₂⋅⎜l₁⋅sin(\theta
# ⎠                         2            ⎟                        ⎜
#                         dt             ⎠                        ⎝
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#                                 d                                   d
# theta₁(t)) + l₂⋅cos(\theta₂(t))⋅──(\theta₂(t)) + l₃⋅cos(\theta₃(t))⋅──(\theta₃
#                                 dt                                  dt
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#      2            ⎞                        ⎛                     2
#     d             ⎟                        ⎜                    d
# ))⋅───(\theta₂(t))⎟⋅cos(\theta₁(t)) + 2⋅l₁⋅⎜l₁⋅sin(\theta₁(t))⋅───(\theta₁(t))
#      2            ⎟                        ⎜                     2
#    dt             ⎠                        ⎝                   dt
# ──────────────────────────────────────────────────────────────────────────────
#
#
#         2                                                  2
#        d                                   ⎛d             ⎞
# ₁(t))⋅───(\theta₁(t)) + l₁⋅cos(\theta₁(t))⋅⎜──(\theta₁(t))⎟  + l₂⋅sin(\theta₂(
#         2                                  ⎝dt            ⎠
#       dt
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                                            ⎛
#                                            ⎜     ⎛                   d
#     ⎞                 d             ⎞   m₃⋅⎜2⋅l₃⋅⎜l₁⋅sin(\theta₁(t))⋅──(\theta
# (t))⎟⋅sin(\theta₃(t))⋅──(\theta₃(t))⎟      ⎜     ⎝                   dt
#     ⎠                 dt            ⎠      ⎝
# ───────────────────────────────────── + ──────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#                                       2                        2
#                       ⎛d             ⎞                        d
#  + l₁⋅cos(\theta₁(t))⋅⎜──(\theta₁(t))⎟  + l₂⋅sin(\theta₂(t))⋅───(\theta₂(t)) +
#                       ⎝dt            ⎠                         2
#                                                              dt
# ──────────────────────────────────────────────────────────────────────────────
#
#
#       2                                                  2⎞                ⎞
#      d                                   ⎛d             ⎞ ⎟                ⎟
# t))⋅───(\theta₂(t)) + l₂⋅cos(\theta₂(t))⋅⎜──(\theta₂(t))⎟ ⎟⋅sin(\theta₂(t))⎟
#       2                                  ⎝dt            ⎠ ⎟                ⎟
#     dt                                                    ⎠                ⎠
# ──────────────────────────────────────────────────────────────────────────── -
#
#
#
#                            d                                   d             ⎞
# ₁(t)) + l₂⋅sin(\theta₂(t))⋅──(\theta₂(t)) + l₃⋅sin(\theta₃(t))⋅──(\theta₃(t))⎟
#                            dt                                  dt            ⎠
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#                                     2⎞                ⎞
#                     ⎛d             ⎞ ⎟                ⎟
#  l₂⋅cos(\theta₂(t))⋅⎜──(\theta₂(t))⎟ ⎟⋅sin(\theta₁(t))⎟      ⎛     ⎛
#                     ⎝dt            ⎠ ⎟                ⎟   m₃⋅⎜2⋅l₁⋅⎜l₁⋅sin(\th
#                                      ⎠                ⎠      ⎝     ⎝
# ─────────────────────────────────────────────────────── - ────────────────────
#
#
#
#
#     ⎛     ⎛                   d                                   d
#  m₃⋅⎜2⋅l₂⋅⎜l₁⋅sin(\theta₁(t))⋅──(\theta₁(t)) + l₂⋅sin(\theta₂(t))⋅──(\theta₂(t
#     ⎝     ⎝                   dt                                  dt
#  ─────────────────────────────────────────────────────────────────────────────
#
#
#
#                  d                     ⎛                   d
# ⋅cos(\theta₃(t))⋅──(\theta₃(t)) - 2⋅l₃⋅⎜l₁⋅cos(\theta₁(t))⋅──(\theta₁(t)) + l₂
#                  dt                    ⎝                   dt
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#          d                                   d
# eta₁(t))⋅──(\theta₁(t)) + l₂⋅sin(\theta₂(t))⋅──(\theta₂(t)) + l₃⋅sin(\theta₃(t
#          dt                                  dt
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#                         d             ⎞                 d
# )) + l₃⋅sin(\theta₃(t))⋅──(\theta₃(t))⎟⋅cos(\theta₂(t))⋅──(\theta₂(t)) - 2⋅l₂⋅
#                         dt            ⎠                 dt
# ──────────────────────────────────────────────────────────────────────────────
#                                                                      2
#
#
#                  d                                   d             ⎞
# ⋅cos(\theta₂(t))⋅──(\theta₂(t)) + l₃⋅cos(\theta₃(t))⋅──(\theta₃(t))⎟⋅sin(\thet
#                  dt                                  dt            ⎠
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#                                                 ⎛     ⎛                   d
#                                              m₄⋅⎜2⋅l₄⋅⎜l₁⋅sin(\theta₁(t))⋅──(\
#                                                 ⎝     ⎝                   dt
#                    g⋅l₄⋅m₄⋅sin(\theta₄(t)) - ─────────────────────────────────
#
#
#
#
#    d             ⎞                 d                     ⎛                   d
# ))⋅──(\theta₃(t))⎟⋅cos(\theta₁(t))⋅──(\theta₁(t)) - 2⋅l₁⋅⎜l₁⋅cos(\theta₁(t))⋅─
#    dt            ⎠                 dt                    ⎝                   d
# ──────────────────────────────────────────────────────────────────────────────
#                                                 2
#
#
#
# ⎛                   d                                   d
# ⎜l₁⋅cos(\theta₁(t))⋅──(\theta₁(t)) + l₂⋅cos(\theta₂(t))⋅──(\theta₂(t)) + l₃⋅co
# ⎝                   dt                                  dt
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                              ⎛                                     2
#        d                     ⎜                     ⎛d             ⎞
# a₃(t))⋅──(\theta₃(t)) + 2⋅l₃⋅⎜- l₁⋅sin(\theta₁(t))⋅⎜──(\theta₁(t))⎟  + l₁⋅cos(
#        dt                    ⎜                     ⎝dt            ⎠
#                              ⎝
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#                                 d                                   d
# theta₁(t)) + l₂⋅sin(\theta₂(t))⋅──(\theta₂(t)) + l₃⋅sin(\theta₃(t))⋅──(\theta₃
#                                 dt                                  dt
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#                                    d                                   d
# ─(\theta₁(t)) + l₂⋅cos(\theta₂(t))⋅──(\theta₂(t)) + l₃⋅cos(\theta₃(t))⋅──(\the
# t                                  dt                                  dt
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                                                                    ⎛
#                                                                    ⎜     ⎛
#               d             ⎞                 d             ⎞   m₃⋅⎜2⋅l₂⋅⎜l₁⋅s
# s(\theta₃(t))⋅──(\theta₃(t))⎟⋅sin(\theta₂(t))⋅──(\theta₂(t))⎟      ⎜     ⎝
#               dt            ⎠                 dt            ⎠      ⎝
# ───────────────────────────────────────────────────────────── + ──────────────
#
#
#               2                                                  2
#              d                                   ⎛d             ⎞
# \theta₁(t))⋅───(\theta₁(t)) - l₂⋅sin(\theta₂(t))⋅⎜──(\theta₂(t))⎟  + l₂⋅cos(\t
#               2                                  ⎝dt            ⎠
#             dt
# ──────────────────────────────────────────────────────────────────────────────
#                                                 2
#
#
#
#                           d             ⎞                 d
# (t)) + l₄⋅sin(\theta₄(t))⋅──(\theta₄(t))⎟⋅cos(\theta₄(t))⋅──(\theta₄(t)) - 2⋅l
#                           dt            ⎠                 dt
# ──────────────────────────────────────────────────────────────────────────────
#                                                                        2
#
#                                               ⎛
#                                               ⎜     ⎛                   d
#        ⎞                 d             ⎞   m₃⋅⎜2⋅l₁⋅⎜l₁⋅sin(\theta₁(t))⋅──(\th
# ta₃(t))⎟⋅sin(\theta₁(t))⋅──(\theta₁(t))⎟      ⎜     ⎝                   dt
#        ⎠                 dt            ⎠      ⎝
# ──────────────────────────────────────── + ───────────────────────────────────
#
#
#
#                d                                   d
# in(\theta₁(t))⋅──(\theta₁(t)) + l₂⋅sin(\theta₂(t))⋅──(\theta₂(t)) + l₃⋅sin(\th
#                dt                                  dt
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#             2                                                  2
#            d                                   ⎛d             ⎞
# heta₂(t))⋅───(\theta₂(t)) - l₃⋅sin(\theta₃(t))⋅⎜──(\theta₃(t))⎟  + l₃⋅cos(\the
#             2                                  ⎝dt            ⎠
#           dt
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#   ⎛                   d                                   d
# ₄⋅⎜l₁⋅cos(\theta₁(t))⋅──(\theta₁(t)) + l₂⋅cos(\theta₂(t))⋅──(\theta₂(t)) + l₃⋅
#   ⎝                   dt                                  dt
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#                               d                                   d
# eta₁(t)) + l₂⋅sin(\theta₂(t))⋅──(\theta₂(t)) + l₃⋅sin(\theta₃(t))⋅──(\theta₃(t
#                               dt                                  dt
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#          d             ⎞                 d                     ⎛
# eta₃(t))⋅──(\theta₃(t))⎟⋅cos(\theta₂(t))⋅──(\theta₂(t)) - 2⋅l₂⋅⎜l₁⋅cos(\theta₁
#          dt            ⎠                 dt                    ⎝
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#           2            ⎞                        ⎛                     2
#          d             ⎟                        ⎜                    d
# ta₃(t))⋅───(\theta₃(t))⎟⋅cos(\theta₃(t)) + 2⋅l₃⋅⎜l₁⋅sin(\theta₁(t))⋅───(\theta
#           2            ⎟                        ⎜                     2
#         dt             ⎠                        ⎝                   dt
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#                 d                                   d             ⎞
# cos(\theta₃(t))⋅──(\theta₃(t)) + l₄⋅cos(\theta₄(t))⋅──(\theta₄(t))⎟⋅sin(\theta
#                 dt                                  dt            ⎠
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#   ⎞                 d                     ⎛                   d
# ))⎟⋅cos(\theta₁(t))⋅──(\theta₁(t)) - 2⋅l₁⋅⎜l₁⋅cos(\theta₁(t))⋅──(\theta₁(t)) +
#   ⎠                 dt                    ⎝                   dt
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#      d                                   d                                   d
# (t))⋅──(\theta₁(t)) + l₂⋅cos(\theta₂(t))⋅──(\theta₂(t)) + l₃⋅cos(\theta₃(t))⋅─
#      dt                                  dt                                  d
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                                            2                        2
#                            ⎛d             ⎞                        d
# ₁(t)) + l₁⋅cos(\theta₁(t))⋅⎜──(\theta₁(t))⎟  + l₂⋅sin(\theta₂(t))⋅───(\theta₂(
#                            ⎝dt            ⎠                         2
#                                                                   dt
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                            ⎛
#                            ⎜     ⎛                   d
#       d             ⎞   m₄⋅⎜2⋅l₄⋅⎜l₁⋅sin(\theta₁(t))⋅──(\theta₁(t)) + l₂⋅sin(\
# ₄(t))⋅──(\theta₄(t))⎟      ⎜     ⎝                   dt
#       dt            ⎠      ⎝
# ───────────────────── + ──────────────────────────────────────────────────────
#
#
#
#                     d                                   d             ⎞
#  l₂⋅cos(\theta₂(t))⋅──(\theta₂(t)) + l₃⋅cos(\theta₃(t))⋅──(\theta₃(t))⎟⋅sin(\t
#                     dt                                  dt            ⎠
#
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                                                      ⎛
#              ⎞                 d                     ⎜                     ⎛d
# ─(\theta₃(t))⎟⋅sin(\theta₂(t))⋅──(\theta₂(t)) + 2⋅l₂⋅⎜- l₁⋅sin(\theta₁(t))⋅⎜──
# t            ⎠                 dt                    ⎜                     ⎝dt
#                                                      ⎝
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                                          2                        2
#                          ⎛d             ⎞                        d
# ...
# ──────────────────────────────────────────────────────────────────────────────
#        2
#
#    2                        2
#   ⎞                        d                                   ⎛d
# ))⎟  + l₃⋅cos(\theta₃(t))⋅───(\theta₃(t)) - l₄⋅sin(\theta₄(t))⋅⎜──(\theta₄(t))
#   ⎠                         2                                  ⎝dt
#                           dt
# ──────────────────────────────────────────────────────────────────────────────
#
#
#                              2⎞                ⎞
#              ⎛d             ⎞ ⎟                ⎟
# (\theta₄(t))⋅⎜──(\theta₄(t))⎟ ⎟⋅sin(\theta₃(t))⎟
#              ⎝dt            ⎠ ⎟                ⎟
#                               ⎠                ⎠
# ────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#        2                                                  2
#       d                                   ⎛d             ⎞
# (t))⋅───(\theta₃(t)) - l₄⋅sin(\theta₄(t))⋅⎜──(\theta₄(t))⎟  + l₄⋅cos(\theta₄(t
#        2                                  ⎝dt            ⎠
#      dt
# ──────────────────────────────────────────────────────────────────────────────
#
#
#  2                        2            ⎞                        ⎛
# ⎞                        d             ⎟                        ⎜
# ⎟  + l₄⋅cos(\theta₄(t))⋅───(\theta₄(t))⎟⋅cos(\theta₂(t)) + 2⋅l₂⋅⎜l₁⋅sin(\theta
# ⎠                         2            ⎟                        ⎜
#                         dt             ⎠                        ⎝
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#      2            ⎞                        ⎛                     2
#     d             ⎟                        ⎜                    d
# ))⋅───(\theta₄(t))⎟⋅cos(\theta₁(t)) + 2⋅l₁⋅⎜l₁⋅sin(\theta₁(t))⋅───(\theta₁(t))
#      2            ⎟                        ⎜                     2
#    dt             ⎠                        ⎝                   dt
# ──────────────────────────────────────────────────────────────────────────────
#
#
#         2                                                  2
#        d                                   ⎛d             ⎞
# ₁(t))⋅───(\theta₁(t)) + l₁⋅cos(\theta₁(t))⋅⎜──(\theta₁(t))⎟  + l₂⋅sin(\theta₂(
#         2                                  ⎝dt            ⎠
#       dt
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                       2                        2
#                       ⎛d             ⎞                        d
#  + l₁⋅cos(\theta₁(t))⋅⎜──(\theta₁(t))⎟  + l₂⋅sin(\theta₂(t))⋅───(\theta₂(t)) +
#                       ⎝dt            ⎠                         2
#                                                              dt
# ──────────────────────────────────────────────────────────────────────────────
#
#
#       2                                                  2
#      d                                   ⎛d             ⎞
# t))⋅───(\theta₂(t)) + l₂⋅cos(\theta₂(t))⋅⎜──(\theta₂(t))⎟  + l₃⋅sin(\theta₃(t)
#       2                                  ⎝dt            ⎠
#     dt
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                     2                        2
#                     ⎛d             ⎞                        d
#  l₂⋅cos(\theta₂(t))⋅⎜──(\theta₂(t))⎟  + l₃⋅sin(\theta₃(t))⋅───(\theta₃(t)) + l
#                     ⎝dt            ⎠                         2
#                                                            dt
# ──────────────────────────────────────────────────────────────────────────────
#
#
#     2                                                  2
#    d                                   ⎛d             ⎞
# )⋅───(\theta₃(t)) + l₃⋅cos(\theta₃(t))⋅⎜──(\theta₃(t))⎟  + l₄⋅sin(\theta₄(t))⋅
#     2                                  ⎝dt            ⎠
#   dt
# ──────────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                   2                        2
#                   ⎛d             ⎞                        d
# ₃⋅cos(\theta₃(t))⋅⎜──(\theta₃(t))⎟  + l₄⋅sin(\theta₄(t))⋅───(\theta₄(t)) + l₄⋅
#                   ⎝dt            ⎠                         2
#                                                          dt
# ──────────────────────────────────────────────────────────────────────────────
#
#
#   2                                                  2⎞                ⎞
#  d                                   ⎛d             ⎞ ⎟                ⎟
# ───(\theta₄(t)) + l₄⋅cos(\theta₄(t))⋅⎜──(\theta₄(t))⎟ ⎟⋅sin(\theta₂(t))⎟
#   2                                  ⎝dt            ⎠ ⎟                ⎟
# dt                                                    ⎠                ⎠
# ────────────────────────────────────────────────────────────────────────
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#                                 2⎞                ⎞⎤
#                 ⎛d             ⎞ ⎟                ⎟⎥
# cos(\theta₄(t))⋅⎜──(\theta₄(t))⎟ ⎟⋅sin(\theta₁(t))⎟⎥
#                 ⎝dt            ⎠ ⎟                ⎟⎥
#                                  ⎠                ⎠⎥
# ───────────────────────────────────────────────────⎥
#                                                    ⎥
#                                                    ⎥
#                                                    ⎥
#                                                    ⎥
#                                                    ⎥
#                                                    ⎥
#                                                    ⎥
#                                                    ⎥
#                                                    ⎥
#                                                    ⎥
#                                                    ⎥
#                                                    ⎥
#                                                    ⎥
#                                                    ⎥
#                                                    ⎥
#                                                    ⎥
#                                                    ⎥
#                                                    ⎥
#                                                    ⎥
#                                                    ⎥
#                                                    ⎥
#                                                    ⎥
#                                                    ⎥
#                                                    ⎥
#                                                    ⎦

# %%
soln1 = sp.simplify(soln[0])
soln2 = sp.simplify(soln[1])
soln3 = sp.simplify(soln[2])
soln4 = sp.simplify(soln[3])

# %%
solution = sp.solve([soln1, soln2, soln3, soln4], (ddv1, ddv2, ddv3, ddv4))

# %%
sp.latex(solution)
