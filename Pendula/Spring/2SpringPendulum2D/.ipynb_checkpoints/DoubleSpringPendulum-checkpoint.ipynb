# %%
from sympy.physics.mechanics import *
import sympy as sp
mechanics_printing(pretty_print=True)

# %%
m1,m2,l01,l02,k1,k2 = sp.symbols(r'm_1,m_2,l_{0\,1},l_{0\,2},k_1,k_2')
t,g = sp.symbols('t,g')
x1, x2, y1, y2, z1, z2 = dynamicsymbols('x_1 x_2 y_1 y_2 z_1 z_2')
dx1, dx2, dy1, dy2, dz1, dz2 = dynamicsymbols('x_1 x_2 y_1 y_2 z_1 z_2', 1)

# %%
V = m1*g*y1+m2*g*y2+sp.Rational(1,2)*k1*(sp.sqrt(x1**2+y1**2+z1**2)-l01)**2+sp.Rational(1,2)*k2*(sp.sqrt((x2-x1)**2+(y2-y1)**2+(z2-z1)**2)-l02)**2
T = sp.Rational(1,2)*m1*(dx1**2+dy1**2+dz1**2)+sp.Rational(1,2)*m2*(dx2**2+dy2**2+dz2**2)
L = sp.simplify(T - V)

# %%
LM = LagrangesMethod(L, [x1, y1, z1, x2, y2, z2])

# %%
soln = LM.form_lagranges_equations()

# %%
solvedsoln = sp.solve((sp.Eq(soln[0]),sp.Eq(soln[1]),sp.Eq(soln[2]),sp.Eq(soln[3]),sp.Eq(soln[4]),sp.Eq(soln[5])),(x1.diff(t,t),y1.diff(t,t),z1.diff(t,t),x2.diff(t,t),y2.diff(t,t),z2.diff(t,t)))

# %%
solvedsoln
# Out:
# ⎧
# ⎪
# ⎪          k₁⋅l_{0,1}⋅x₁        k₁⋅x₁                                k₂⋅l_{0,2
# ⎨x₁̈: ─────────────────────── - ───── + ──────────────────────────────────────
# ⎪           _________________     m₁          ________________________________
# ⎪          ╱   2     2     2                 ╱   2               2     2
# ⎩     m₁⋅╲╱  x₁  + y₁  + z₁             m₁⋅╲╱  x₁  - 2⋅x₁⋅x₂ + x₂  + y₁  - 2⋅y
#
#
#
# }⋅x₁                                                             k₂⋅l_{0,2}⋅x₂
# ───────────────────────────────── - ──────────────────────────────────────────
# _________________________________         ____________________________________
#          2     2               2         ╱   2               2     2
# ₁⋅y₂ + y₂  + z₁  - 2⋅z₁⋅z₂ + z₂     m₁⋅╲╱  x₁  - 2⋅x₁⋅x₂ + x₂  + y₁  - 2⋅y₁⋅y₂
#
#                                                        ⎛
#                                                        ⎜
#                                 k₂⋅x₁   k₂⋅x₂       k₂⋅⎝l_{0,2}⋅(-x₁ + x₂) + (
# ───────────────────────────── - ───── + ─────, x₂̈: ──────────────────────────
# _____________________________     m₁      m₁                              ____
#      2     2               2                                             ╱   2
#  + y₂  + z₁  - 2⋅z₁⋅z₂ + z₂                                         m₂⋅╲╱  x₁
#
#             _________________________________________________________________⎞
#            ╱   2               2     2               2     2               2 ⎟
# x₁ - x₂)⋅╲╱  x₁  - 2⋅x₁⋅x₂ + x₂  + y₁  - 2⋅y₁⋅y₂ + y₂  + z₁  - 2⋅z₁⋅z₂ + z₂  ⎠
# ──────────────────────────────────────────────────────────────────────────────
# _____________________________________________________________
#                2     2               2     2               2
#  - 2⋅x₁⋅x₂ + x₂  + y₁  - 2⋅y₁⋅y₂ + y₂  + z₁  - 2⋅z₁⋅z₂ + z₂
#
#
#
#                  k₁⋅l_{0,1}⋅y₁        k₁⋅y₁                                k₂⋅
# , y₁̈: -g + ─────────────────────── - ───── + ────────────────────────────────
#                   _________________     m₁          __________________________
#                  ╱   2     2     2                 ╱   2               2     2
#             m₁⋅╲╱  x₁  + y₁  + z₁             m₁⋅╲╱  x₁  - 2⋅x₁⋅x₂ + x₂  + y₁
#
#
#
# l_{0,2}⋅y₁                                                             k₂⋅l_{0
# ─────────────────────────────────────── - ────────────────────────────────────
# _______________________________________         ______________________________
#                2     2               2         ╱   2               2     2
#  - 2⋅y₁⋅y₂ + y₂  + z₁  - 2⋅z₁⋅z₂ + z₂     m₁⋅╲╱  x₁  - 2⋅x₁⋅x₂ + x₂  + y₁  - 2
#
#
#
# ,2}⋅y₂                                k₂⋅y₁   k₂⋅y₂
# ─────────────────────────────────── - ───── + ─────, y₂̈: -g - ───────────────
# ___________________________________     m₁      m₁                   _________
#            2     2               2                                  ╱   2
# ⋅y₁⋅y₂ + y₂  + z₁  - 2⋅z₁⋅z₂ + z₂                              m₂⋅╲╱  x₁  - 2⋅
#
#
#
#               k₂⋅l_{0,2}⋅y₁
# ──────────────────────────────────────────────────────── + ───────────────────
# ________________________________________________________         _____________
#           2     2               2     2               2         ╱   2
# x₁⋅x₂ + x₂  + y₁  - 2⋅y₁⋅y₂ + y₂  + z₁  - 2⋅z₁⋅z₂ + z₂     m₂⋅╲╱  x₁  - 2⋅x₁⋅x
#
#
#
#           k₂⋅l_{0,2}⋅y₂                                k₂⋅y₁   k₂⋅y₂
# ──────────────────────────────────────────────────── + ───── - ─────, z₁̈: ───
# ____________________________________________________     m₂      m₂
#       2     2               2     2               2
# ₂ + x₂  + y₁  - 2⋅y₁⋅y₂ + y₂  + z₁  - 2⋅z₁⋅z₂ + z₂                         m₁⋅
#
#
#
#   k₁⋅l_{0,1}⋅z₁        k₁⋅z₁                                k₂⋅l_{0,2}⋅z₁
# ──────────────────── - ───── + ───────────────────────────────────────────────
#    _________________     m₁          _________________________________________
#   ╱   2     2     2                 ╱   2               2     2
# ╲╱  x₁  + y₁  + z₁             m₁⋅╲╱  x₁  - 2⋅x₁⋅x₂ + x₂  + y₁  - 2⋅y₁⋅y₂ + y₂
#
#
#
#                                                         k₂⋅l_{0,2}⋅z₂
# ──────────────────────── - ───────────────────────────────────────────────────
# ________________________         _____________________________________________
# 2     2               2         ╱   2               2     2               2
#   + z₁  - 2⋅z₁⋅z₂ + z₂     m₁⋅╲╱  x₁  - 2⋅x₁⋅x₂ + x₂  + y₁  - 2⋅y₁⋅y₂ + y₂  +
#
#                                               ⎛
#                                               ⎜
#                        k₂⋅z₁   k₂⋅z₂       k₂⋅⎝l_{0,2}⋅(-z₁ + z₂) + (z₁ - z₂)⋅
# ──────────────────── - ───── + ─────, z₂̈: ───────────────────────────────────
# ____________________     m₁      m₁                              _____________
#   2               2                                             ╱   2
# z₁  - 2⋅z₁⋅z₂ + z₂                                         m₂⋅╲╱  x₁  - 2⋅x₁⋅x
#
#    _________________________________________________________________⎞⎫
#   ╱   2               2     2               2     2               2 ⎟⎪
# ╲╱  x₁  - 2⋅x₁⋅x₂ + x₂  + y₁  - 2⋅y₁⋅y₂ + y₂  + z₁  - 2⋅z₁⋅z₂ + z₂  ⎠⎪
# ─────────────────────────────────────────────────────────────────────⎬
# ____________________________________________________                 ⎪
#       2     2               2     2               2                  ⎪
# ₂ + x₂  + y₁  - 2⋅y₁⋅y₂ + y₂  + z₁  - 2⋅z₁⋅z₂ + z₂                   ⎭
